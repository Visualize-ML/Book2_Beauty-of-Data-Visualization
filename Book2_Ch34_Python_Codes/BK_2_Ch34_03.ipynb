# %% [markdown]
# Chapter 34
# # 外旋轮线Epitrochoid
# Book_2《可视之美》 | 鸢尾花书：从加减乘除到机器学习

# %% [markdown]
# 参考：
# https://en.wikipedia.org/wiki/Epitrochoid
# https://mathworld.wolfram.com/Epitrochoid.html

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import lcm

# %% [markdown]
# ## 自定义函数

# %%
def draw_spirograph(R, r, d):
    
    num = lcm(R,r)/R
    print(num)
    theta = np.linspace(0,num*2*np.pi, 10000)
    theta_cir = np.linspace(0,2*np.pi,180)
    
    x = (R+r) * np.cos(theta) - d * np.cos((R+r)/r * theta)
    y = (R+r) * np.sin(theta) - d * np.sin((R+r)/r * theta)
    
    fig, ax = plt.subplots(figsize = (3,3))
    
    plt.plot(0, 0, marker = 'x', markersize = 6)

    plt.plot(x, y, c='k')
    
    # 大圆圆周
    plt.plot(np.cos(theta_cir) * R, 
             np.sin(theta_cir) * R,
             lw = 0.2, c = 'b', ls = '--')
    
    # 小圆圆心运动轨迹
    plt.plot(np.cos(theta_cir) * (R + r), 
             np.sin(theta_cir) * (R + r),
             lw = 0.2, c = 'k', ls = 'dashed')
    
    plt.plot(np.cos(theta_cir) * r + (R + r), 
             np.sin(theta_cir) * r,
             lw = 1, c = 'r')
    
    plt.plot(R + r, 0, marker = 'x', c = 'r', markersize = 6)
    
    # P点位置
    plt.plot(R + r - d, 0, marker = '.', c = 'k', markersize = 6)
    
    plt.xlim(-R-3,R+3)
    plt.ylim(-R-3,R+3)
    # plt.axis('equal')
    plt.axis('off')
    plt.savefig('R = ' + str(R) + ', r = ' + str(r) + ', d = ' + str(d) + '.svg')
    plt.show()

# %% [markdown]
# ## R = 1, r = 1

# %%
draw_spirograph(1, 1, 0)
# Out:
# 1.0

# %%
draw_spirograph(1, 1, 0.5)
# Out:
# 1.0

# %%
draw_spirograph(1, 1, 1)
# Out:
# 1.0

# %%
draw_spirograph(1, 1, 2)
# Out:
# 1.0

# %% [markdown]
# ## R = 2, r = 1

# %%
draw_spirograph(2, 1, 0)
# Out:
# 1.0

# %%
draw_spirograph(2, 1, 0.5)
# Out:
# 1.0

# %%
draw_spirograph(2, 1, 1)
# Out:
# 1.0

# %%
draw_spirograph(2, 1, 2)
# Out:
# 1.0

# %% [markdown]
# ## R = 3, r = 1

# %%
draw_spirograph(3, 1, 0)
# Out:
# 1.0

# %%
draw_spirograph(3, 1, 0.5)
# Out:
# 1.0

# %%
draw_spirograph(3, 1, 1)
# Out:
# 1.0

# %%
draw_spirograph(3, 1, 2)
# Out:
# 1.0

# %% [markdown]
# ## R = 4, r = 1

# %%
draw_spirograph(4, 1, 0)
# Out:
# 1.0

# %%
draw_spirograph(4, 1, 0.5)
# Out:
# 1.0

# %%
draw_spirograph(4, 1, 1)
# Out:
# 1.0

# %%
draw_spirograph(4, 1, 2)
# Out:
# 1.0

# %% [markdown]
# ## R = 5, r = 1

# %%
draw_spirograph(5, 1, 0)
# Out:
# 1.0

# %%
draw_spirograph(5, 1, 0.5)
# Out:
# 1.0

# %%
draw_spirograph(5, 1, 1)
# Out:
# 1.0

# %%
draw_spirograph(5, 1, 2)
# Out:
# 1.0

# %% [markdown]
# ## R = 6, r = 1

# %%
draw_spirograph(6, 1, 0)
# Out:
# 1.0

# %%
draw_spirograph(6, 1, 0.5)
# Out:
# 1.0

# %%
draw_spirograph(6, 1, 1)
# Out:
# 1.0

# %%
draw_spirograph(6, 1, 2)
# Out:
# 1.0

# %% [markdown]
# ## R = 7, r = 1

# %%
draw_spirograph(7, 1, 0)
# Out:
# 1.0

# %%
draw_spirograph(7, 1, 0.5)
# Out:
# 1.0

# %%
draw_spirograph(7, 1, 1)
# Out:
# 1.0

# %%
draw_spirograph(7, 1, 2)
# Out:
# 1.0

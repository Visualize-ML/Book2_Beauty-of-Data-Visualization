# %% [markdown]
# Chapter 22
# # 星形曲线Astroid
# Book_2《可视之美》 | 鸢尾花书：从加减乘除到机器学习

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as patches

import os

# 如果文件夹不存在，创建文件夹
if not os.path.isdir("Figures"):
    os.makedirs("Figures")

# %%
x = np.linspace(-2,2,num = 1001)
y = np.linspace(-2,2,num = 1001)

xx,yy = np.meshgrid(x,y);

c_array = np.linspace(0, 1,num = 31)

# %%
fig, ax = plt.subplots(figsize=(5, 5))

colors = plt.cm.rainbow(np.linspace(0,1,len(c_array)))

for i in range(0,len(c_array)):
    
    c_i = c_array[i]
    
    ellipse = (xx/c_i)**2 + (yy/(1-c_i))**2
    
    color_code = colors[i,:].tolist()

    plt.contour(xx,yy,ellipse,
                levels = [1], colors = [color_code], 
                linewidths = 0.25)

# plt.axvline(x = 0, color = 'k', linestyle = '-')
# plt.axhline(y = 0, color = 'k', linestyle = '-')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlim([-1.1,1.1])
ax.set_ylim([-1.1,1.1])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.axis('off')
fig.savefig('1.svg')
# fig.savefig('Figures/和给定矩形相切的一组椭圆.svg', format='svg')
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_588\2182016792.py:9: RuntimeWarning: divide by zero encountered in divide
#   ellipse = (xx/c_i)**2 + (yy/(1-c_i))**2
# C:\Users\james\AppData\Local\Temp\ipykernel_588\2182016792.py:9: RuntimeWarning: invalid value encountered in divide
#   ellipse = (xx/c_i)**2 + (yy/(1-c_i))**2
# C:\Users\james\AppData\Local\Temp\ipykernel_588\2182016792.py:13: UserWarning: No contour levels were found within the data range.
#   plt.contour(xx,yy,ellipse,

# %%
def visualize(loc_x,loc_y):
    
    for i in range(0,len(c_array)):

        c_i = c_array[i]

        ellipse = ((xx - loc_x)/c_i)**2 + ((yy - loc_y)/(1-c_i))**2

        plt.contour(xx,yy,ellipse,
                    levels = [1], colors = '0.5', 
                    linewidths = 0.25)

# %%
fig, ax = plt.subplots(figsize=(8, 8))

loc_x = np.arange(-2,3)
loc_y = loc_x

loc_xx,loc_yy = np.meshgrid(loc_x,loc_y)

for loc_x,loc_y in zip(loc_xx.ravel(),loc_yy.ravel()):
    
    visualize(loc_x,loc_y)

# # plt.axvline(x = 0, color = 'k', linestyle = '-')
# # plt.axhline(y = 0, color = 'k', linestyle = '-')
# ax.set_xticks([])
# ax.set_yticks([])
# # ax.set_xlim([-2,2])
# # ax.set_ylim([-2,2])

ax.axis('off')
fig.savefig('2.svg')
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_588\1277339550.py:7: RuntimeWarning: divide by zero encountered in divide
#   ellipse = ((xx - loc_x)/c_i)**2 + ((yy - loc_y)/(1-c_i))**2
# C:\Users\james\AppData\Local\Temp\ipykernel_588\1277339550.py:7: RuntimeWarning: invalid value encountered in divide
#   ellipse = ((xx - loc_x)/c_i)**2 + ((yy - loc_y)/(1-c_i))**2
# C:\Users\james\AppData\Local\Temp\ipykernel_588\1277339550.py:9: UserWarning: No contour levels were found within the data range.
#   plt.contour(xx,yy,ellipse,

# %% [markdown]
# 参考：
# https://mathworld.wolfram.com/Astroid.html

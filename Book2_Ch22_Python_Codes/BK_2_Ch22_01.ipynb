# %% [markdown]
# Chapter 22
# # 绘制线段
# Book_2《可视之美》 | 鸢尾花书：从加减乘除到机器学习

# %%
# 导入包
import matplotlib.pyplot as plt
import numpy as np

import os

# 如果文件夹不存在，创建文件夹
if not os.path.isdir("Figures"):
    os.makedirs("Figures")

# %%
x = np.linspace(-4,4,num = 1001)
y = np.linspace(-4,4,num = 1001)

xx,yy = np.meshgrid(x,y);

# %% [markdown]
# ## 绘制 x + y = c

# %%
fig, ax = plt.subplots(figsize=(5, 5))
levels = np.arange(-6,6 + 1)
CS = plt.contour(xx,yy,xx + yy,
            levels = levels, 
            cmap = 'rainbow',
            inline = True)

ax.clabel(CS, inline=True, fontsize=10)

ax.axvline(x = 0, color = 'k', linestyle = '-')
ax.axhline(y = 0, color = 'k', linestyle = '-')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlim([-4,4])
ax.set_ylim([-4,4])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid()

fig.savefig('Figures/直线，1.svg', format='svg')
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_12160\1351676604.py:3: UserWarning: The following kwargs were not used by contour: 'inline'
#   CS = plt.contour(xx,yy,xx + yy,

# %% [markdown]
# ## 绘制 x - y = c

# %%
fig, ax = plt.subplots(figsize=(5, 5))
levels = np.arange(-6,6 + 1)
CS = plt.contour(xx,yy,xx - yy,
            levels = levels, 
            cmap = 'rainbow',
            inline = True)

ax.clabel(CS, inline=True, fontsize=10)

ax.axvline(x = 0, color = 'k', linestyle = '-')
ax.axhline(y = 0, color = 'k', linestyle = '-')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlim([-4,4])
ax.set_ylim([-4,4])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid()

fig.savefig('Figures/直线，2.svg', format='svg')
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_12160\3159519771.py:3: UserWarning: The following kwargs were not used by contour: 'inline'
#   CS = plt.contour(xx,yy,xx - yy,

# %% [markdown]
# ## 绘制 x + 2*y = c

# %%
fig, ax = plt.subplots(figsize=(5, 5))
levels = np.arange(-6,6 + 1)
CS = plt.contour(xx,yy,xx + 2*yy,
            levels = levels, 
            cmap = 'rainbow',
            inline = True)

ax.clabel(CS, inline=True, fontsize=10)

ax.axvline(x = 0, color = 'k', linestyle = '-')
ax.axhline(y = 0, color = 'k', linestyle = '-')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlim([-4,4])
ax.set_ylim([-4,4])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid()

fig.savefig('Figures/直线，3.svg', format='svg')
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_12160\1432867085.py:3: UserWarning: The following kwargs were not used by contour: 'inline'
#   CS = plt.contour(xx,yy,xx + 2*yy,

# %% [markdown]
# ## 绘制 2*x - y = c

# %%
fig, ax = plt.subplots(figsize=(5, 5))
levels = np.arange(-6,6 + 1)
CS = plt.contour(xx,yy,2*xx - yy,
            levels = levels, 
            cmap = 'rainbow',
            inline = True)

ax.clabel(CS, inline=True, fontsize=10)

ax.axvline(x = 0, color = 'k', linestyle = '-')
ax.axhline(y = 0, color = 'k', linestyle = '-')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlim([-4,4])
ax.set_ylim([-4,4])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid()

fig.savefig('Figures/直线，4.svg', format='svg')
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_12160\3966309799.py:3: UserWarning: The following kwargs were not used by contour: 'inline'
#   CS = plt.contour(xx,yy,2*xx - yy,

# %% [markdown]
# ## 绘制 x = c

# %%
fig, ax = plt.subplots(figsize=(5, 5))
levels = np.arange(-3,3 + 1)
CS = plt.contour(xx,yy,xx,
            levels = levels, 
            cmap = 'rainbow',
            inline = True)

ax.clabel(CS, inline=True, fontsize=10)

ax.axvline(x = 0, color = 'k', linestyle = '-')
ax.axhline(y = 0, color = 'k', linestyle = '-')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlim([-4,4])
ax.set_ylim([-4,4])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid()

fig.savefig('Figures/直线，5.svg', format='svg')
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_12160\3679929167.py:3: UserWarning: The following kwargs were not used by contour: 'inline'
#   CS = plt.contour(xx,yy,xx,

# %% [markdown]
# ## 绘制 y = c

# %%
fig, ax = plt.subplots(figsize=(5, 5))
levels = np.arange(-3,3 + 1)
CS = plt.contour(xx,yy,yy,
            levels = levels, 
            cmap = 'rainbow',
            inline = True)

ax.clabel(CS, inline=True, fontsize=10)

ax.axvline(x = 0, color = 'k', linestyle = '-')
ax.axhline(y = 0, color = 'k', linestyle = '-')
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlim([-4,4])
ax.set_ylim([-4,4])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid()

fig.savefig('Figures/直线，6.svg', format='svg')
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_12160\1283872346.py:3: UserWarning: The following kwargs were not used by contour: 'inline'
#   CS = plt.contour(xx,yy,yy,
